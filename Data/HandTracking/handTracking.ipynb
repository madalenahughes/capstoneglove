# %%
# !pip install -q mediapipe

# %%
# !wget -q https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task
# Out:
# zsh:1: command not found: wget

# %%
#@markdown We implemented some functions to visualize the hand landmark detection results. <br/> Run the following cell to activate the functions.
import mediapipe as mp
import numpy as np

mp_hands = mp.tasks.vision.HandLandmarksConnections
mp_drawing = mp.tasks.vision.drawing_utils
mp_drawing_styles = mp.tasks.vision.drawing_styles

MARGIN = 10  # pixels
FONT_SIZE = 1
FONT_THICKNESS = 1
HANDEDNESS_TEXT_COLOR = (88, 205, 54) # vibrant green

def draw_landmarks_on_image(rgb_image, detection_result):
  hand_landmarks_list = detection_result.hand_landmarks
  handedness_list = detection_result.handedness
  annotated_image = np.copy(rgb_image)

  # Loop through the detected hands to visualize.
  for idx in range(len(hand_landmarks_list)):
    hand_landmarks = hand_landmarks_list[idx]
    handedness = handedness_list[idx]

    # Draw the hand landmarks.
    mp_drawing.draw_landmarks(
      annotated_image,
      hand_landmarks,
      mp_hands.HAND_CONNECTIONS,
      mp_drawing_styles.get_default_hand_landmarks_style(),
      mp_drawing_styles.get_default_hand_connections_style())

    # Get the top left corner of the detected hand's bounding box.
    height, width, _ = annotated_image.shape
    x_coordinates = [landmark.x for landmark in hand_landmarks]
    y_coordinates = [landmark.y for landmark in hand_landmarks]
    text_x = int(min(x_coordinates) * width)
    text_y = int(min(y_coordinates) * height) - MARGIN

    # Draw handedness (left or right hand) on the image.
    cv2.putText(annotated_image, f"{handedness[0].category_name}",
                (text_x, text_y), cv2.FONT_HERSHEY_DUPLEX,
                FONT_SIZE, HANDEDNESS_TEXT_COLOR, FONT_THICKNESS, cv2.LINE_AA)

  return annotated_image

# %%
# STEP 1: Import the necessary modules.
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision

# STEP 2: Create an HandLandmarker object.
base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
options = vision.HandLandmarkerOptions(base_options=base_options,
                                       num_hands=2)
detector = vision.HandLandmarker.create_from_options(options)

# STEP 3: Load the input image.
image = mp.Image.create_from_file("image.jpg")

# STEP 4: Detect hand landmarks from the input image.
detection_result = detector.detect(image)

# STEP 5: Process the classification result. In this case, visualize it.
annotated_image = draw_landmarks_on_image(image.numpy_view(), detection_result)
cv2_imshow(cv2.cvtColor(annotated_image, cv2.COLOR_RGB2BGR))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 10
#       7 base_options = python.BaseOptions(model_asset_path='hand_landmarker.task')
#       8 options = vision.HandLandmarkerOptions(base_options=base_options,
#       9                                        num_hands=2)
# ---> 10 detector = vision.HandLandmarker.create_from_options(options)
#      12 # STEP 3: Load the input image.
#      13 image = mp.Image.create_from_file("image.jpg")
#
# File ~/GitHub/capstoneglove/.venv/lib/python3.13/site-packages/mediapipe/tasks/python/vision/hand_landmarker.py:422, in HandLandmarker.create_from_options(cls, options)
#     411 ctypes_options = HandLandmarkerOptionsC.from_c_options(
#     412     base_options=options.base_options.to_ctypes(),
#     413     running_mode=options.running_mode,
#    (...)    418     result_callback=c_callback,
#     419 )
#     421 landmarker_handle = ctypes.c_void_p()
# --> 422 lib.MpHandLandmarkerCreate(
#     423     ctypes.byref(ctypes_options),
#     424     ctypes.byref(landmarker_handle),
#     425 )
#     426 return HandLandmarker(
#     427     lib=lib,
#     428     handle=landmarker_handle,
#     429     dispatcher=dispatcher,
#     430     async_callback=c_callback,
#     431 )
#
# File ~/GitHub/capstoneglove/.venv/lib/python3.13/site-packages/mediapipe/tasks/python/core/serial_dispatcher.py:74, in SerialDispatcher._register_signature.<locals>.shutdown_aware_handler(*args, **kwargs)
#      72   if self._is_closed:
#      73     return
# ---> 74 return handler(*args, **kwargs)
#
# File ~/GitHub/capstoneglove/.venv/lib/python3.13/site-packages/mediapipe/tasks/python/core/mediapipe_c_utils.py:142, in CStatusFunction.create_python_wrapper.<locals>.dispatcher_wrapper(*args, **kwargs)
#     139     if error_msg.value is not None:
#     140       lib.MpErrorFree(error_msg)
# --> 142 executor.submit(dispatch_and_free).result()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~/GitHub/capstoneglove/.venv/lib/python3.13/site-packages/mediapipe/tasks/python/core/mediapipe_c_utils.py:137, in CStatusFunction.create_python_wrapper.<locals>.dispatcher_wrapper.<locals>.dispatch_and_free()
#     135 status = c_func(*call_args, **kwargs)
#     136 try:
# --> 137   handle_status(status, error_msg)
#     138 finally:
#     139   if error_msg.value is not None:
#
# File ~/GitHub/capstoneglove/.venv/lib/python3.13/site-packages/mediapipe/tasks/python/core/mediapipe_c_utils.py:232, in handle_status(status, error_message)
#     230 exception = convert_to_exception(status, error_message)
#     231 if exception:
# --> 232   raise exception
#
# FileNotFoundError: Unable to open file at hand_landmarker.task
